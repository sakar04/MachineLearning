# %%
import pandas as pd

# %%
#This shoude be available in the git hub as I made changes

# %%
s1 = pd.Series([10,20,30,40,50,60])

# %%
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
s2 = pd.Series([10,20,30,40,50,60], index = ['a','b','c','d','e','f'], name = "Scores")

# %%
print(s2)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# Name: Scores, dtype: int64

# %%
data = {'a':10, 'b': 20, 'c': 30, 'd': 40}

# %%
s3 = pd.Series(data)
print(s3)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
import numpy as np
np_array = pd.array([10,20,30,40])
s4 = pd.Series(np_array)
print(s4)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: Int64

# %%
data = {'a': 10, 'b':1.1, 'c':"Hello", 'd':True}

# %%
s5 = pd.Series(data)

# %%
print(s5)
# Out:
# a       10
# b      1.1
# c    Hello
# d     True
# dtype: object

# %%
data = {'a':10, 'b':True, 1: 1.1, 2: "Hello"}
s5 = pd.Series(data)
print(s5)
# Out:
# a       10
# b     True
# 1      1.1
# 2    Hello
# dtype: object

# %%
data = {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
s6 = pd.Series(data, name = 'Scores')

# %%
print(s6)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: Scores, dtype: int64

# %%
print(s6.index)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
print(s6.values)
# Out:
# [10 20 30 40]

# %%
print(s6.dtype)
# Out:
# int64

# %%
print(s6.name)
# Out:
# Scores

# %%
print(s6)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: Scores, dtype: int64

# %%
print(s6.loc['a'])
# Out:
# 10

# %%
print(s6.iloc[0])
# Out:
# 10

# %%
print(s6[0])
# Out:
# 10
# C:\Users\aukar\AppData\Local\Temp\ipykernel_29012\37769319.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s6[0])

# %%
data = { 'a':10, 'b':20, 'c':30, 'd':40, 0:100, 1:101, 2:400, 6:700}
s7 = pd.Series(data)
print(s7)
# Out:
# a     10
# b     20
# c     30
# d     40
# 0    100
# 1    101
# 2    400
# 6    700
# dtype: int64

# %%
s7.loc[0:2]
# Out:
# 0    100
# 1    101
# 2    400
# dtype: int64

# %%
s7.loc[0:6]#final index is inclusive
# Out:
# 0    100
# 1    101
# 2    400
# 6    700
# dtype: int64

# %%
data = {
    'Name': ['Anant','Pushpak','Nikhil'],
    'Age': [24, 26, 28],
    'City': ['Bengaluru','Hyderabad','Pune']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0    Anant   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28       Pune

# %%
data_1 = [
    {'Name':'Anant', 'Age':'24', 'City':'Bengaluru'},
    {'Name':'Pushpak', 'Age':'26', 'City':'Hyderabad'},
    {'Name':'Nikhil', 'Age':'28', 'City': 'Pune'}

]

# %%
df_1 = pd.DataFrame(data_1)
print(df_1)
# Out:
#       Name Age       City
# 0    Anant  24  Bengaluru
# 1  Pushpak  26  Hyderabad
# 2   Nikhil  28       Pune

# %%
arr_data = np.array([[1,2],[3,4],[5,6]])

# %%
df_2 = pd.DataFrame(arr_data)
print(df_2)
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df_2 = pd.DataFrame(arr_data, columns=['A','B'])
print(df_2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6

# %%
data = {
    'Name': ['Anant','Pushpak','Nikhil'],
    'Age': [24, 26, 28],
    'City': ['Bengaluru','Hyderabad','Pune']
}

# %%
df_4 = pd.DataFrame(data)
print(df_4)
# Out:
#       Name  Age       City
# 0    Anant   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28       Pune

# %%
print(df_4['Name'])
print("="*40)
print(df_4[['Name','Age']])
print("="*40)
print(df_4.loc[0])
print("="*40)
print(df_4.loc[0:1])
print("="*40)
print(df_4.iloc[0])
print("="*40)
print(df_4.iloc[0:1])
# Out:
# 0      Anant
# 1    Pushpak
# 2     Nikhil
# Name: Name, dtype: object
# ========================================
#       Name  Age
# 0    Anant   24
# 1  Pushpak   26
# 2   Nikhil   28
# ========================================
# Name        Anant
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#       Name  Age       City
# 0    Anant   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# ========================================
# Name        Anant
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#     Name  Age       City
# 0  Anant   24  Bengaluru

# %%
df = pd.read_csv("titanic.csv")

# %%
#preview of data frame
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#last 5 rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.tail())
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0,3]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df[df['Age']>70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[df['Age']<20]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 7      male   2.0      3      1   349909  21.0750   NaN        S
# 9    female  14.0      1      0   237736  30.0708   NaN        C
# 10   female   4.0      1      1  PP 9549  16.7000    G6        S
# 14   female  14.0      0      0   350406   7.8542   NaN        S
# 16     male   2.0      4      1   382652  29.1250   NaN        Q
# ..      ...   ...    ...    ...      ...      ...   ...      ...
# 855  female  18.0      0      1   392091   9.3500   NaN        S
# 869    male   4.0      1      1   347742  11.1333   NaN        S
# 875  female  15.0      0      0     2667   7.2250   NaN        C
# 877    male  19.0      0      0   349212   7.8958   NaN        S
# 887  female  19.0      0      0   112053  30.0000   B42        S
#
# [164 rows x 12 columns]

# %%
older_pass = df[df['Age']>70]

# %%
older_pass
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
#identify number of females that survived
df[(df['Sex'] == 'female') & df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]

# %%
#identify number of females that survived
female_survivor_subset = df[(df['Sex'] == 'female') & df['Survived'] == 1][['Name','Age']]

# %%
female_survivor_subset
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
#
# [233 rows x 2 columns]

# %%
female_survivor_subset.head()
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
female_survivor_subset.head(10)
# Out:
#                                                  Name   Age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0
# 11                           Bonnell, Miss. Elizabeth  58.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   55.0
# 19                            Masselmani, Mrs. Fatima   NaN
# 22                        McGowan, Miss. Anna "Annie"  15.0

# %%
#total number of survivors
print(len(df[df['Survived'] == 1]))
# Out:
# 342

# %%
survived = len(df[df['Survived'] == 1])
not_survived = len(df[df['Survived'] == 0])
print(survived+not_survived)
# Out:
# 891

# %%
survived/(survived+not_survived)
# Out:
# 0.3838383838383838

# %%
not_survived/(survived+not_survived)
# Out:
# 0.6161616161616161

# %%
female_survivors_subset_loc = df.loc[(df['Sex']=='female') & (df['Survived']== 1),['Name','Age']]
female_survivors_subset_loc
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
#
# [233 rows x 2 columns]

# %%
df.loc[0,'Cabin']#instead of 0, we have put the condition
# Out:
# nan

# %%
#number of survivors
print(len(df[df['Survived']==1]))
# Out:
# 342

# %%
#Slicing rows and columns
df.loc[0:4,['Name','Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df.iloc[0:3, 0:2]
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1

# %%
df.iloc[0:3,0:3:2]
# Out:
#    PassengerId  Pclass
# 0            1       3
# 1            2       1
# 2            3       3

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0:3,[1,3]]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina

# %%
df.iloc[0:3,[3,1]]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1

# %%
df.loc[0:2,['Survived','Name']]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina

# %%
df.loc[0:2,['Name','Survived']]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
subset = df[df['Sex']== 'male']
subset['Age'] = subset['Age'] + 1
print(subset)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    23.0      1      0         A/5 21171   7.2500   NaN        S
# 4    36.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    55.0      0      0             17463  51.8625   E46        S
# 7     3.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  29.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  26.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  28.0      0      0            211536  13.0000   NaN        S
# 889  27.0      0      0            111369  30.0000  C148        C
# 890  33.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]
# C:\Users\aukar\AppData\Local\Temp\ipykernel_39768\1238005537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Age'] = subset['Age'] + 1

# %%
subset = df[df['Sex']=='male'].copy()
subset['Age'] += 1
print(subset)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    23.0      1      0         A/5 21171   7.2500   NaN        S
# 4    36.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    55.0      0      0             17463  51.8625   E46        S
# 7     3.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  29.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  26.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  28.0      0      0            211536  13.0000   NaN        S
# 889  27.0      0      0            111369  30.0000  C148        C
# 890  33.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_by_name = df.set_index('Name')
df_by_name.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S

# %%
print(df_by_name.loc['Allen, Mr. William Henry'])
# Out:
# PassengerId         5
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Cabin             NaN
# Embarked            S
# Name: Allen, Mr. William Henry, dtype: object

# %%
df_by_name = df_by_name.reset_index()
df_by_name.head()
# Out:
#    index                                               Name  PassengerId  \
# 0      0                            Braund, Mr. Owen Harris            1
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2      2                             Heikkinen, Miss. Laina            3
# 3      3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4      4                           Allen, Mr. William Henry            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
#reindex
sales_jan = pd.DataFrame({
    'Sales': [250, 400, 300]
}, index = ['Store_A','Store_B', 'Store_C'])
sales_jan
# Out:
#          Sales
# Store_A    250
# Store_B    400
# Store_C    300

# %%
sales_feb = pd.DataFrame({
    'Sales': [260,310]
}, index = ['Store_A', 'Store_C'])
sales_feb
# Out:
#          Sales
# Store_A    260
# Store_C    310

# %%
common_index = sales_jan.index

# %%
sales_feb_aligned = sales_feb.reindex(common_index)

# %%
sales_feb_aligned
# Out:
#          Sales
# Store_A  260.0
# Store_B    NaN
# Store_C  310.0

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']

# %%
sales_diff
# Out:
# Store_A    10.0
# Store_B     NaN
# Store_C    10.0
# Name: Sales, dtype: float64

# %%
sales_feb_aligned = sales_feb.reindex(common_index, fill_value=0)
sales_feb_aligned
# Out:
#          Sales
# Store_A    260
# Store_B      0
# Store_C    310

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']
sales_diff
# Out:
# Store_A     10
# Store_B   -400
# Store_C     10
# Name: Sales, dtype: int64

# %%
source_a = pd.DataFrame({
    'Product' : ['Laptop','Tablet','Phone'],
    'Price' : [1000, 500, 800],
    'Stock' : [30, 50, 100]
}
)
source_a
# Out:
#   Product  Price  Stock
# 0  Laptop   1000     30
# 1  Tablet    500     50
# 2   Phone    800    100

# %%
source_b = pd.DataFrame({
    'Price': [980, 520, 810],
    'Product': ['Laptop','Tablet', 'Phone']
})
source_b
# Out:
#    Price Product
# 0    980  Laptop
# 1    520  Tablet
# 2    810   Phone

# %%
aligned_b = source_b.reindex(columns=source_a.columns, fill_value=0)
aligned_b
# Out:
#   Product  Price  Stock
# 0  Laptop    980      0
# 1  Tablet    520      0
# 2   Phone    810      0

# %%
#iteration in pandas
df = pd.DataFrame({
    'Name': ['Heartine','Gagan','Gavin'],
    'Age': [25, 20, 23],
    'City': ['Delhi','Mumbai','Chennai']
})

# %%
for index, row in df.iterrows():
    #print(index, row, end='\n\n')
    print(f"{index}: {row['Name']} lives in {row['City']} and is {row['Age']} years old.")
# Out:
# 0: Heartine lives in Delhi and is 25 years old.
# 1: Gagan lives in Mumbai and is 20 years old.
# 2: Gavin lives in Chennai and is 23 years old.

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Name='Heartine', Age=25, City='Delhi')
# Pandas(Index=1, Name='Gagan', Age=20, City='Mumbai')
# Pandas(Index=2, Name='Gavin', Age=23, City='Chennai')

# %%
for row in df.itertuples():
    print(row.Name)
# Out:
# Heartine
# Gagan
# Gavin

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
for i in df.index:
    print(i)
# Out:
# 0
# 1
# 2

# %%
for col in df.columns:
    print(f"Columns: {col}")
    print(df[col].values, end="\n\n")
# Out:
# Columns: Name
# ['Heartine' 'Gagan' 'Gavin']
#
# Columns: Age
# [25 20 23]
#
# Columns: City
# ['Delhi' 'Mumbai' 'Chennai']

# %%
#condition based column creation using custom logic
df.head()
# Out:
#        Name  Age     City
# 0  Heartine   25    Delhi
# 1     Gagan   20   Mumbai
# 2     Gavin   23  Chennai

# %%
df
# Out:
#        Name  Age     City
# 0  Heartine   25    Delhi
# 1     Gagan   20   Mumbai
# 2     Gavin   23  Chennai

# %%
#if age>20 then senior, else young
values = []
for idx, row in df.iterrows():
    if row['Age']<20:
        values.append("young")
    else:
        values.append("senior")


df['Category'] = values

# %%
df
# Out:
#        Name  Age     City Category
# 0  Heartine   25    Delhi   senior
# 1     Gagan   20   Mumbai   senior
# 2     Gavin   23  Chennai   senior

# %%
#vectorized using apply
df = pd.DataFrame({
    'Name': ['Heartine','Gagan','Gavin'],
    'Age': [25, 20, 23],
    'City': ['Delhi','Mumbai','Chennai']
})

# %%
df
# Out:
#        Name  Age     City
# 0  Heartine   25    Delhi
# 1     Gagan   20   Mumbai
# 2     Gavin   23  Chennai

# %%
df['Categories'] = df['Age'].apply(lambda age: 'young' if age < 30 else 'senior')

# %%
df
# Out:
#        Name  Age     City Categories
# 0  Heartine   25    Delhi      young
# 1     Gagan   20   Mumbai      young
# 2     Gavin   23  Chennai      young

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sorted_df = df.sort_values(by="Age")
sorted_df[['Name','Age']].head(5)
# Out:
#                                 Name   Age
# 803  Thomas, Master. Assad Alexander  0.42
# 755        Hamalainen, Master. Viljo  0.67
# 644           Baclini, Miss. Eugenie  0.75
# 469    Baclini, Miss. Helene Barbara  0.75
# 78     Caldwell, Master. Alden Gates  0.83

# %%
sorted_df[["Name","Age"]].tail()
# Out:
#                                          Name  Age
# 859                          Razi, Mr. Raihed  NaN
# 863         Sage, Miss. Dorothy Edith "Dolly"  NaN
# 868               van Melkebeke, Mr. Philemon  NaN
# 878                        Laleff, Mr. Kristo  NaN
# 888  Johnston, Miss. Catherine Helen "Carrie"  NaN

# %%
sorted_df.loc[0:100,["Name","Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 289                               Connolly, Miss. Kate  22.0
# 323  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  22.0
# 243                      Maenpaa, Mr. Matti Alexanteri  22.0
# 521                                    Vovk, Mr. Janko  22.0
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# 399                   Trout, Mrs. William H (Jessie L)  28.0
# 392                       Gustafsson, Mr. Johan Birger  28.0
# 635                                  Davis, Miss. Mary  28.0
# 100                            Petranec, Miss. Matilda  28.0
#
# [146 rows x 2 columns]

# %%
print(df['Age'].dtype)
# Out:
# float64

# %%
df['Age'] = df['Age'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df['Age'] = df['Age'].astype('int64')
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\aukar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df['Age'] = df['Age'].fillna(0).astype('int64')

# %%
print(df['Age'].dtype)
# Out:
# int64

# %%
sorted_df = df.sort_values(by="Age")
print(sorted_df[["Name","Age"]].tail(20))
# Out:
#                                           Name  Age
# 625                      Sutton, Mr. Frederick   61
# 570                         Harris, Mr. George   62
# 829  Stone, Mrs. George Nelson (Martha Evelyn)   62
# 252                  Stead, Mr. William Thomas   62
# 555                         Wright, Mr. George   62
# 275          Andrews, Miss. Kornelia Theodosia   63
# 483                     Turkula, Mrs. (Hedwig)   63
# 545               Nicholson, Mr. Arthur Ernest   64
# 438                          Fortune, Mr. Mark   64
# 54              Ostby, Mr. Engelhart Cornelius   65
# 456                  Millet, Mr. Francis Davis   65
# 280                           Duane, Mr. Frank   65
# 33                       Wheadon, Mr. Edward H   66
# 116                       Connors, Mr. Patrick   70
# 745               Crosby, Capt. Edward Gifford   70
# 672                Mitchell, Mr. Henry Michael   70
# 493                    Artagaveytia, Mr. Ramon   71
# 96                   Goldschmidt, Mr. George B   71
# 851                        Svensson, Mr. Johan   74
# 630       Barkworth, Mr. Algernon Henry Wilson   80

# %%
print(sorted_df[["Name","Age"]].head(20))
# Out:
#                                          Name  Age
# 28              O'Dwyer, Miss. Ellen "Nellie"    0
# 306                   Fleming, Miss. Margaret    0
# 457         Kenyon, Mrs. Frederick R (Marion)    0
# 454                       Peduzzi, Mr. Joseph    0
# 451           Hagland, Mr. Ingvald Olai Olsen    0
# 305            Allison, Master. Hudson Trevor    0
# 527                        Farthing, Mr. John    0
# 653             O'Leary, Miss. Hanora "Norah"    0
# 444         Johannesen-Bratthammer, Mr. Bernt    0
# 650                         Mitkoff, Mr. Mito    0
# 481          Frost, Mr. Anthony Wood "Archie"    0
# 648                        Willey, Mr. Edward    0
# 644                    Baclini, Miss. Eugenie    0
# 643                           Foo, Mr. Choong    0
# 888  Johnston, Miss. Catherine Helen "Carrie"    0
# 846                  Sage, Mr. Douglas Bullen    0
# 17               Williams, Mr. Charles Eugene    0
# 82             McDermott, Miss. Brigdet Delia    0
# 78              Caldwell, Master. Alden Gates    0
# 77                   Moutal, Mr. Rahamin Haim    0

# %%
#sort by multiple columns
df_sorted = df.sort_values(by=['Pclass','Fare'])

# %%
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 263          264         0       1            Harrison, Mr. William  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 263   40      0      0  112059   0.0   B94        S
# 633    0      0      0  112052   0.0   NaN        S
# 806   39      0      0  112050   0.0   A36        S
# 815    0      0      0  112058   0.0  B102        S
# 822   38      0      0   19972   0.0   NaN        S

# %%
df_sorted = df.sort_values(by=['Pclass','Fare'], ascending=[True,False])

# %%
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex  Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female   35      0      0  PC 17755  512.3292          NaN        C
# 679    male   36      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male   35      0      0  PC 17755  512.3292         B101        C
# 27     male   19      3      2     19950  263.0000  C23 C25 C27        S
# 88   female   23      3      2     19950  263.0000  C23 C25 C27        S

# %%
#axis=0 rows
#axis=1 columns
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_sort_2=df.set_index('PassengerId')

# %%
df_sorted_by_index = df_sort_2.sort_index()

# %%
df_sorted_by_index.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df_sort_2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# ...                                                        ...     ...  ...
# 887                                      Montvila, Rev. Juozas    male   27
# 888                               Graham, Miss. Margaret Edith  female   19
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female    0
# 890                                      Behr, Mr. Karl Howell    male   26
# 891                                        Dooley, Mr. Patrick    male   32
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df_sorted_by_index_c = df_sort_2.sort_index(axis=1)

# %%
df_sorted_by_index_c
# Out:
#              Age Cabin Embarked     Fare  \
# PassengerId
# 1             22   NaN        S   7.2500
# 2             38   C85        C  71.2833
# 3             26   NaN        S   7.9250
# 4             35  C123        S  53.1000
# 5             35   NaN        S   8.0500
# ...          ...   ...      ...      ...
# 887           27   NaN        S  13.0000
# 888           19   B42        S  30.0000
# 889            0   NaN        S  23.4500
# 890           26  C148        C  30.0000
# 891           32   NaN        Q   7.7500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# ...                                                        ...    ...     ...
# 887                                      Montvila, Rev. Juozas      0       2
# 888                               Graham, Miss. Margaret Edith      0       1
# 889                   Johnston, Miss. Catherine Helen "Carrie"      2       3
# 890                                      Behr, Mr. Karl Howell      0       1
# 891                                        Dooley, Mr. Patrick      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# 3            female      0         1  STON/O2. 3101282
# 4            female      1         1            113803
# 5              male      0         0            373450
# ...             ...    ...       ...               ...
# 887            male      0         0            211536
# 888          female      0         1            112053
# 889          female      1         0        W./C. 6607
# 890            male      0         1            111369
# 891            male      0         0            370376
#
# [891 rows x 11 columns]

# %%
df_sorted_by_index
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# ...                                                        ...     ...  ...
# 887                                      Montvila, Rev. Juozas    male   27
# 888                               Graham, Miss. Margaret Edith  female   19
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female    0
# 890                                      Behr, Mr. Karl Howell    male   26
# 891                                        Dooley, Mr. Patrick    male   32
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df_sorted_by_index = df_sorted_by_index.sort_index(axis=0, ascending=False)

# %%
df_sorted_by_index.head()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 891                 0       3                       Dooley, Mr. Patrick
# 890                 1       1                     Behr, Mr. Karl Howell
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 888                 1       1              Graham, Miss. Margaret Edith
# 887                 0       2                     Montvila, Rev. Juozas
#
#                 Sex  Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 891            male   32      0      0      370376   7.75   NaN        Q
# 890            male   26      0      0      111369  30.00  C148        C
# 889          female    0      1      2  W./C. 6607  23.45   NaN        S
# 888          female   19      0      0      112053  30.00   B42        S
# 887            male   27      0      0      211536  13.00   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    0      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_sorted_cols = df.sort_index(axis=1)

# %%
df_sorted_cols.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1         0         A/5 21171
# 1       1  female      1         1          PC 17599
# 2       3  female      0         1  STON/O2. 3101282
# 3       1  female      1         1            113803
# 4       3    male      0         0            373450

# %%
#changing column order in pandas
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_order = ['Name', 'Sex', 'Age','Pclass','Fare','Survived']

# %%
df_reordered = df[new_order]
df_reordered.head()
# Out:
#                                                 Name     Sex   Age  Pclass  \
# 0                            Braund, Mr. Owen Harris    male  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                             Heikkinen, Miss. Laina  female  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                           Allen, Mr. William Henry    male  35.0       3
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sorted(df.columns)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket']

# %%
df_reordered = df[sorted(df.columns)]

# %%
df_reordered
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas      0          887
# 887                       Graham, Miss. Margaret Edith      0          888
# 888           Johnston, Miss. Catherine Helen "Carrie"      2          889
# 889                              Behr, Mr. Karl Howell      0          890
# 890                                Dooley, Mr. Patrick      0          891
#
#      Pclass     Sex  SibSp  Survived            Ticket
# 0         3    male      1         0         A/5 21171
# 1         1  female      1         1          PC 17599
# 2         3  female      0         1  STON/O2. 3101282
# 3         1  female      1         1            113803
# 4         3    male      0         0            373450
# ..      ...     ...    ...       ...               ...
# 886       2    male      0         0            211536
# 887       1  female      0         1            112053
# 888       3  female      1         0        W./C. 6607
# 889       1    male      0         1            111369
# 890       3    male      0         0            370376
#
# [891 rows x 12 columns]

# %%
#working with text data
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df[["Name","Sex","Cabin"]].head(3))
# Out:
#                                                 Name     Sex Cabin
# 0                            Braund, Mr. Owen Harris    male   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                             Heikkinen, Miss. Laina  female   NaN

# %%
print(df['Name'].str.lower())
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
print(df['Name'].str.upper())
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
print(df['Name'].str.capitalize())
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
print(df['Name'].str.len())
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
df['Name'].str.replace("Mr.","Sir",regex=False).head()
# Out:
# 0                              Braund, Sir Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Sir William Henry
# Name: Name, dtype: object

# %%
df['Name'].str.replace(r"\(.*\)","",regex=True).head()
# Out:
# 0          Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley
# 2           Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath
# 4         Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#Extract with regex
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Title'] = df['Name'].str.extract(r'(\(.*\))',expand=False)

# %%
df['Title']
# Out:
# 0                           NaN
# 1      (Florence Briggs Thayer)
# 2                           NaN
# 3               (Lily May Peel)
# 4                           NaN
#                  ...
# 886                         NaN
# 887                         NaN
# 888                         NaN
# 889                         NaN
# 890                         NaN
# Name: Title, Length: 891, dtype: object

# %%
type(df['Name'].str.extract(r'(\(.*\))',expand=True))
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'].str.extract(r'(\(.*\))',expand=False))
# Out:
# pandas.core.series.Series

# %%
#split and access elements
df['Name'][0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df['Name'].str.split(",", expand=False)[0]
# Out:
# ['Braund', ' Mr. Owen Harris']

# %%
df['Name'].str.split(",",expand=True)[0]
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.split(" ",expand=True)[0]
# Out:
# 0         Braund,
# 1        Cumings,
# 2      Heikkinen,
# 3       Futrelle,
# 4          Allen,
#           ...
# 886     Montvila,
# 887       Graham,
# 888     Johnston,
# 889         Behr,
# 890       Dooley,
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.split(expand=True)[0]
# Out:
# 0         Braund,
# 1        Cumings,
# 2      Heikkinen,
# 3       Futrelle,
# 4          Allen,
#           ...
# 886     Montvila,
# 887       Graham,
# 888     Johnston,
# 889         Behr,
# 890       Dooley,
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.lstrip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.rstrip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#Find position of substring
df['Name'].str.find("Mr.")
# Out:
# 0      8
# 1     -1
# 2     -1
# 3     -1
# 4      7
#       ..
# 886   -1
# 887   -1
# 888   -1
# 889    6
# 890    8
# Name: Name, Length: 891, dtype: int64

# %%
#count number of passengers with "Miss" in name
count = df['Name'].str.contains("Miss").sum()
print("Number of 'Miss': ", count)
# Out:
# Number of 'Miss':  182

# %%
data = {
    'Name':['Sandeep','Sudeep','Riya','Madhuri'],
    'Email': ['sk@gmail.com','s@gamil.com', 'r@gmail.com','m@gmail.com']
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       Name         Email
# 0  Sandeep  sk@gmail.com
# 1   Sudeep   s@gamil.com
# 2     Riya   r@gmail.com
# 3  Madhuri   m@gmail.com

# %%
df['Name'].str.replace("Sandeep","Sumit",regex=False)
# Out:
# 0      Sumit
# 1     Sudeep
# 2       Riya
# 3    Madhuri
# Name: Name, dtype: object

# %%
df
# Out:
#       Name         Email
# 0  Sandeep  sk@gmail.com
# 1   Sudeep   s@gamil.com
# 2     Riya   r@gmail.com
# 3  Madhuri   m@gmail.com

# %%
df['Name'].str.replace("sandeep","Rohit",regex=False)
# Out:
# 0    Sandeep
# 1     Sudeep
# 2       Riya
# 3    Madhuri
# Name: Name, dtype: object

# %%
df['Name'].str.pad(width=20,side='left',fillchar='-')
# Out:
# 0    -------------Sandeep
# 1    --------------Sudeep
# 2    ----------------Riya
# 3    -------------Madhuri
# Name: Name, dtype: object

# %%
df['Name'].str.pad(width=20, side='right',fillchar='-')
# Out:
# 0    Sandeep-------------
# 1    Sudeep--------------
# 2    Riya----------------
# 3    Madhuri-------------
# Name: Name, dtype: object

# %%
#Options and customizations
df = pd.read_csv("titanic.csv")

# %%
pd.set_option('display.max_rows',5)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0  A/5 21171   7.2500   NaN        S
# 1        0   PC 17599  71.2833   C85        C
# ..     ...        ...      ...   ...      ...
# 889      0     111369  30.0000  C148        C
# 890      0     370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#show all columns
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0  A/5 21171   7.2500   NaN        S
# 1        0   PC 17599  71.2833   C85        C
# ..     ...        ...      ...   ...      ...
# 889      0     111369  30.0000  C148        C
# 890      0     370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns',3)

# %%
df
# Out:
#      PassengerId  ...  Embarked
# 0              1  ...         S
# 1              2  ...         C
# ..           ...  ...       ...
# 889          890  ...         C
# 890          891  ...         Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[['Fare','Age']].head()
# Out:
#       Fare   Age
# 0   7.2500  22.0
# 1  71.2833  38.0
# 2   7.9250  26.0
# 3  53.1000  35.0
# 4   8.0500  35.0

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
df[['Fare','Age']].head()
# Out:
#    Fare   Age
# 0  7.25 22.00
# 1 71.28 38.00
# 2  7.92 26.00
# 3 53.10 35.00
# 4  8.05 35.00

# %%
pd.get_option('display.max_rows')
# Out:
# 5

# %%
with pd.option_context('display.max_rows',3):#to work with sessions
    print(df)
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male 22.00
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male 32.00
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# ..                                                 ...     ...   ...    ...
# 889                              Behr, Mr. Karl Howell    male 26.00      0
# 890                                Dooley, Mr. Patrick    male 32.00      0
#
#      Parch     Ticket  Fare Cabin Embarked
# 0        0  A/5 21171  7.25   NaN        S
# 1        0   PC 17599 71.28   C85        C
# ..     ...        ...   ...   ...      ...
# 889      0     111369 30.00  C148        C
# 890      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.reset_option('display.max_rows')

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.reset_option('all')
# Out:
# C:\Users\aukar\AppData\Local\Temp\ipykernel_39768\2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\aukar\AppData\Local\Temp\ipykernel_39768\2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore',FutureWarning)
    pd.reset_option('all')

# %%
#categorical data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df['Sex'].dtype)
# Out:
# object

# %%
#convert a column to categorical
df['Sex_C'] = df['Sex'].astype('category')

# %%
df[['Sex','Sex_C']].head()
# Out:
#       Sex   Sex_C
# 0    male    male
# 1  female  female
# 2  female  female
# 3  female  female
# 4    male    male

# %%
print(df['Sex'].dtype)
print(df['Sex_C'].dtype)
# Out:
# object
# category

# %%
print(df['Sex_C'].cat.codes.head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# dtype: int8

# %%
df['Sex_C_Categorical_Codes'] = df['Sex_C'].cat.codes

# %%
df[['Sex','Sex_C','Sex_C_Categorical_Codes']].head()
# Out:
#       Sex   Sex_C  Sex_C_Categorical_Codes
# 0    male    male                        1
# 1  female  female                        0
# 2  female  female                        0
# 3  female  female                        0
# 4    male    male                        1

# %%
df['Sex_apply_category']= df['Sex'].apply(lambda x:0 if x == 'male' else 1)

# %%
df[['Sex','Sex_C','Sex_C_Categorical_Codes','Sex_apply_category']].head()
# Out:
#       Sex   Sex_C  Sex_C_Categorical_Codes  Sex_apply_category
# 0    male    male                        1                   0
# 1  female  female                        0                   1
# 2  female  female                        0                   1
# 3  female  female                        0                   1
# 4    male    male                        1                   0

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
#Date Functionality in Pandas
df = pd.DataFrame({
    'Event': ['Concert','Conference','Wedding'],
    'Date' : ['2025-01-01','2025-03-15','2025-07-20']
})

# %%
df
# Out:
#         Event        Date
# 0     Concert  2025-01-01
# 1  Conference  2025-03-15
# 2     Wedding  2025-07-20

# %%
df['date_pandas'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Event        Date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15
# 2     Wedding  2025-07-20  2025-07-20

# %%
print(df.dtypes[['Event','Date','date_pandas']])
# Out:
# Event                  object
# Date                   object
# date_pandas    datetime64[ns]
# dtype: object

# %%
df['date_pandas'].dt.year
# Out:
# 0    2025
# 1    2025
# 2    2025
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.month
# Out:
# 0    1
# 1    3
# 2    7
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day
# Out:
# 0     1
# 1    15
# 2    20
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.weekday
# Out:
# 0    2
# 1    5
# 2    6
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day_name()
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Sunday
# Name: date_pandas, dtype: object

# %%
df['date_pandas'].dt.is_month_end
# Out:
# 0    False
# 1    False
# 2    False
# Name: date_pandas, dtype: bool

# %%
df[df['date_pandas'] > '2025-04-01']
# Out:
#      Event        Date date_pandas
# 2  Wedding  2025-07-20  2025-07-20

# %%
df[df['date_pandas'].between('2025-01-01','2025-06-01')]
# Out:
#         Event        Date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15

# %%
#date range
pd.date_range(start='2024-01-01',end='2024-01-10',freq='D')
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2025-01-01', end='2025-04-30', freq='ME')
# Out:
# DatetimeIndex(['2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start='2025-01-01', end='2025-04-30', freq='MS')
# Out:
# DatetimeIndex(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01'], dtype='datetime64[ns]', freq='MS')

# %%
#Date Arithmetic
df['next_week'] = df['date_pandas'] + pd.Timedelta(days=7)

# %%
df
# Out:
#         Event        Date date_pandas  next_week
# 0     Concert  2025-01-01  2025-01-01 2025-01-08
# 1  Conference  2025-03-15  2025-03-15 2025-03-22
# 2     Wedding  2025-07-20  2025-07-20 2025-07-27

# %%
df['days_to_event'] = df['date_pandas'] - pd.Timestamp.today()

# %%
df
# Out:
#         Event        Date date_pandas  next_week              days_to_event
# 0     Concert  2025-01-01  2025-01-01 2025-01-08 -193 days +15:53:26.265274
# 1  Conference  2025-03-15  2025-03-15 2025-03-22 -120 days +15:53:26.265274
# 2     Wedding  2025-07-20  2025-07-20 2025-07-27     7 days 15:53:26.265274
